# %%
# Requires clientside communication install of Azures Custom Vision API
# `pip install azure-cognitiveservices-vision-customvision`
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateBatch
from msrest.authentication import ApiKeyCredentials 

import os
import numpy as np

# %%
# Azure Communication
ENDPOINT = "https://animaldetectioninstance.cognitiveservices.azure.com/"
training_key = "ede65e3546354b29aece9806ff96932a"
credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
publish_iteration_name = "classifyAnimalModel"
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

project = trainer.create_project("Animal Classification")

# %%
os.chdir('./General_Animal_Detection_Photos')

# Classify each species by the folder it's contained in
tags = [name for name in os.listdir('.') if os.path.isdir(name)]

# %%
def createTag(tag_name):
    # Create a new tag in the Custom Vision project
    tag = trainer.create_tag(project.id, tag_name)
    return tag.id

def createImageList(tag, tag_id):
# Set directory to current tag.
   base_image_url = f"./{tag}/"
   photo_name_list = os.listdir(base_image_url)
   image_list = []
   for file_name in photo_name_list:
       with open(base_image_url+file_name, "rb") as image_contents:
           image_list.append(ImageFileCreateEntry(name=base_image_url+file_name, contents=image_contents.read(), tag_ids=[tag_id]))
   return image_list

def uploadImageList(image_list):
      upload_result = trainer.create_images_from_files(project_id=project.id, batch=image_list)
      if not upload_result.is_batch_successful:
         print("Image batch upload failed.")
         for image in upload_result.images:
              print("Image status: ", image.status)
         exit(-1)

# %%
for tag in tags:
    tag_id = createTag(tag)
    print(f"tag creation done with tag id {tag_id}")
    image_list = createImageList(tag, tag_id)
    print("image_list created with length " + str(len(image_list)))

    # Depending on the ammount of transactions, the upload batch sizes should be changed. (Currently 50)
    for i in range(0, len(image_list), 25):
        batch = ImageFileCreateBatch(images=image_list[i:i + 25])
        print(f'Upload started for batch {i} total items {len(image_list)} for tag {tag}...')
        uploadImageList(batch)
        print(f"Batch {i} Image upload completed. Total uploaded {len(image_list)} for tag {tag}")
# Out:
# tag creation done with tag id 2a16169b-1d14-442a-9479-3b7bbab1965a
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag antelope...
# Batch 0 Image upload completed. Total uploaded 60 for tag antelope
# Upload started for batch 25 total items 60 for tag antelope...
# Batch 25 Image upload completed. Total uploaded 60 for tag antelope
# Upload started for batch 50 total items 60 for tag antelope...
# Batch 50 Image upload completed. Total uploaded 60 for tag antelope
# tag creation done with tag id d79abee5-7cdf-478e-954e-e705f8be60b8
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag badger...
# Batch 0 Image upload completed. Total uploaded 60 for tag badger
# Upload started for batch 25 total items 60 for tag badger...
# Batch 25 Image upload completed. Total uploaded 60 for tag badger
# Upload started for batch 50 total items 60 for tag badger...
# Batch 50 Image upload completed. Total uploaded 60 for tag badger
# tag creation done with tag id 215007b6-cbe4-4c74-9c5f-6d0668862de5
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag bat...
# Batch 0 Image upload completed. Total uploaded 60 for tag bat
# Upload started for batch 25 total items 60 for tag bat...
# Batch 25 Image upload completed. Total uploaded 60 for tag bat
# Upload started for batch 50 total items 60 for tag bat...
# Batch 50 Image upload completed. Total uploaded 60 for tag bat
# tag creation done with tag id 2555dd86-af14-4feb-b2e7-94d909e0465f
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag bear...
# Batch 0 Image upload completed. Total uploaded 60 for tag bear
# Upload started for batch 25 total items 60 for tag bear...
# Batch 25 Image upload completed. Total uploaded 60 for tag bear
# Upload started for batch 50 total items 60 for tag bear...
# Batch 50 Image upload completed. Total uploaded 60 for tag bear
# tag creation done with tag id 76da1f35-b5af-4abf-b199-fe6a999aa160
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag bee...
# Batch 0 Image upload completed. Total uploaded 60 for tag bee
# Upload started for batch 25 total items 60 for tag bee...
# Batch 25 Image upload completed. Total uploaded 60 for tag bee
# Upload started for batch 50 total items 60 for tag bee...
# Batch 50 Image upload completed. Total uploaded 60 for tag bee
# tag creation done with tag id 7ec2c156-d8a3-4975-bc8d-fd3a54528f0f
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag beetle...
# Batch 0 Image upload completed. Total uploaded 60 for tag beetle
# Upload started for batch 25 total items 60 for tag beetle...
# Batch 25 Image upload completed. Total uploaded 60 for tag beetle
# Upload started for batch 50 total items 60 for tag beetle...
# Batch 50 Image upload completed. Total uploaded 60 for tag beetle
# tag creation done with tag id 315b37b1-879e-4633-a341-80cfc909d96f
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag bison...
# Batch 0 Image upload completed. Total uploaded 60 for tag bison
# Upload started for batch 25 total items 60 for tag bison...
# Batch 25 Image upload completed. Total uploaded 60 for tag bison
# Upload started for batch 50 total items 60 for tag bison...
# Batch 50 Image upload completed. Total uploaded 60 for tag bison
# tag creation done with tag id 1f7cb803-eaa9-4cfc-8b63-9cd996174f3a
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag boar...
# Batch 0 Image upload completed. Total uploaded 60 for tag boar
# Upload started for batch 25 total items 60 for tag boar...
# Batch 25 Image upload completed. Total uploaded 60 for tag boar
# Upload started for batch 50 total items 60 for tag boar...
# Batch 50 Image upload completed. Total uploaded 60 for tag boar
# tag creation done with tag id 59396c20-1c08-431b-a515-2615b2813124
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag butterfly...
# Batch 0 Image upload completed. Total uploaded 60 for tag butterfly
# Upload started for batch 25 total items 60 for tag butterfly...
# Batch 25 Image upload completed. Total uploaded 60 for tag butterfly
# Upload started for batch 50 total items 60 for tag butterfly...
# Batch 50 Image upload completed. Total uploaded 60 for tag butterfly
# tag creation done with tag id f667a9fb-a57e-452e-b26e-f955b1a4af63
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag cat...
# Batch 0 Image upload completed. Total uploaded 60 for tag cat
# Upload started for batch 25 total items 60 for tag cat...
# Batch 25 Image upload completed. Total uploaded 60 for tag cat
# Upload started for batch 50 total items 60 for tag cat...
# Batch 50 Image upload completed. Total uploaded 60 for tag cat
# tag creation done with tag id ec96014f-4fdf-48c8-9a96-2a9f3a1c7ebf
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag caterpillar...
# Batch 0 Image upload completed. Total uploaded 60 for tag caterpillar
# Upload started for batch 25 total items 60 for tag caterpillar...
# Batch 25 Image upload completed. Total uploaded 60 for tag caterpillar
# Upload started for batch 50 total items 60 for tag caterpillar...
# Batch 50 Image upload completed. Total uploaded 60 for tag caterpillar
# tag creation done with tag id 250619c8-b80a-41eb-b4ee-20611d07a8f1
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag chimpanzee...
# Batch 0 Image upload completed. Total uploaded 60 for tag chimpanzee
# Upload started for batch 25 total items 60 for tag chimpanzee...
# Batch 25 Image upload completed. Total uploaded 60 for tag chimpanzee
# Upload started for batch 50 total items 60 for tag chimpanzee...
# Batch 50 Image upload completed. Total uploaded 60 for tag chimpanzee
# tag creation done with tag id 6bccc3bd-1343-484b-90c4-c2cd1ba0a3b6
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag cockroach...
# Batch 0 Image upload completed. Total uploaded 60 for tag cockroach
# Upload started for batch 25 total items 60 for tag cockroach...
# Batch 25 Image upload completed. Total uploaded 60 for tag cockroach
# Upload started for batch 50 total items 60 for tag cockroach...
# Batch 50 Image upload completed. Total uploaded 60 for tag cockroach
# tag creation done with tag id 775ecd9e-df6d-43fe-ad57-8805b64ef1b1
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag cow...
# Batch 0 Image upload completed. Total uploaded 60 for tag cow
# Upload started for batch 25 total items 60 for tag cow...
# Batch 25 Image upload completed. Total uploaded 60 for tag cow
# Upload started for batch 50 total items 60 for tag cow...
# Batch 50 Image upload completed. Total uploaded 60 for tag cow
# tag creation done with tag id b09d2dea-9b88-4462-85d7-dc1c57cc0493
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag coyote...
# Batch 0 Image upload completed. Total uploaded 60 for tag coyote
# Upload started for batch 25 total items 60 for tag coyote...
# Batch 25 Image upload completed. Total uploaded 60 for tag coyote
# Upload started for batch 50 total items 60 for tag coyote...
# Batch 50 Image upload completed. Total uploaded 60 for tag coyote
# tag creation done with tag id 809453db-d1bd-4656-85ba-63088e20f2c4
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag crab...
# Batch 0 Image upload completed. Total uploaded 60 for tag crab
# Upload started for batch 25 total items 60 for tag crab...
# Batch 25 Image upload completed. Total uploaded 60 for tag crab
# Upload started for batch 50 total items 60 for tag crab...
# Batch 50 Image upload completed. Total uploaded 60 for tag crab
# tag creation done with tag id 709e7e2d-59e8-487a-8259-cbd2bde57640
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag crow...
# Batch 0 Image upload completed. Total uploaded 60 for tag crow
# Upload started for batch 25 total items 60 for tag crow...
# Batch 25 Image upload completed. Total uploaded 60 for tag crow
# Upload started for batch 50 total items 60 for tag crow...
# Batch 50 Image upload completed. Total uploaded 60 for tag crow
# tag creation done with tag id 18e125d5-a29f-418b-b9d8-ed3e9e67d891
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag deer...
# Batch 0 Image upload completed. Total uploaded 60 for tag deer
# Upload started for batch 25 total items 60 for tag deer...
# Batch 25 Image upload completed. Total uploaded 60 for tag deer
# Upload started for batch 50 total items 60 for tag deer...
# Batch 50 Image upload completed. Total uploaded 60 for tag deer
# tag creation done with tag id d6c4acd1-71ff-46b1-938a-a6f71b2ae364
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag dog...
# Batch 0 Image upload completed. Total uploaded 60 for tag dog
# Upload started for batch 25 total items 60 for tag dog...
# Batch 25 Image upload completed. Total uploaded 60 for tag dog
# Upload started for batch 50 total items 60 for tag dog...
# Batch 50 Image upload completed. Total uploaded 60 for tag dog
# tag creation done with tag id 4a0b3fac-1913-4529-bffb-fdef7c1b728d
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag dolphin...
# Batch 0 Image upload completed. Total uploaded 60 for tag dolphin
# Upload started for batch 25 total items 60 for tag dolphin...
# Batch 25 Image upload completed. Total uploaded 60 for tag dolphin
# Upload started for batch 50 total items 60 for tag dolphin...
# Batch 50 Image upload completed. Total uploaded 60 for tag dolphin
# tag creation done with tag id e32a1334-308e-495f-b24b-91fe5547c648
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag donkey...
# Batch 0 Image upload completed. Total uploaded 60 for tag donkey
# Upload started for batch 25 total items 60 for tag donkey...
# Batch 25 Image upload completed. Total uploaded 60 for tag donkey
# Upload started for batch 50 total items 60 for tag donkey...
# Batch 50 Image upload completed. Total uploaded 60 for tag donkey
# tag creation done with tag id 67cab4b8-4314-4a4a-8944-fcc225ff3711
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag dragonfly...
# Batch 0 Image upload completed. Total uploaded 60 for tag dragonfly
# Upload started for batch 25 total items 60 for tag dragonfly...
# Batch 25 Image upload completed. Total uploaded 60 for tag dragonfly
# Upload started for batch 50 total items 60 for tag dragonfly...
# Batch 50 Image upload completed. Total uploaded 60 for tag dragonfly
# tag creation done with tag id 3fa8d5ae-d702-4a45-aa11-5dc976c3e047
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag duck...
# Batch 0 Image upload completed. Total uploaded 60 for tag duck
# Upload started for batch 25 total items 60 for tag duck...
# Batch 25 Image upload completed. Total uploaded 60 for tag duck
# Upload started for batch 50 total items 60 for tag duck...
# Batch 50 Image upload completed. Total uploaded 60 for tag duck
# tag creation done with tag id 853d30ad-371b-4c78-8b14-2f79095ae96d
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag eagle...
# Batch 0 Image upload completed. Total uploaded 60 for tag eagle
# Upload started for batch 25 total items 60 for tag eagle...
# Batch 25 Image upload completed. Total uploaded 60 for tag eagle
# Upload started for batch 50 total items 60 for tag eagle...
# Batch 50 Image upload completed. Total uploaded 60 for tag eagle
# tag creation done with tag id e25f2b3f-a675-48a2-82b9-f28edb013a32
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag elephant...
# Batch 0 Image upload completed. Total uploaded 60 for tag elephant
# Upload started for batch 25 total items 60 for tag elephant...
# Batch 25 Image upload completed. Total uploaded 60 for tag elephant
# Upload started for batch 50 total items 60 for tag elephant...
# Batch 50 Image upload completed. Total uploaded 60 for tag elephant
# tag creation done with tag id 4b2cc553-f5b5-4e84-9b38-0fe72b102741
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag flamingo...
# Batch 0 Image upload completed. Total uploaded 60 for tag flamingo
# Upload started for batch 25 total items 60 for tag flamingo...
# Batch 25 Image upload completed. Total uploaded 60 for tag flamingo
# Upload started for batch 50 total items 60 for tag flamingo...
# Batch 50 Image upload completed. Total uploaded 60 for tag flamingo
# tag creation done with tag id b18ef16d-16f9-42a7-899d-9b9b45d0d37e
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag fly...
# Batch 0 Image upload completed. Total uploaded 60 for tag fly
# Upload started for batch 25 total items 60 for tag fly...
# Batch 25 Image upload completed. Total uploaded 60 for tag fly
# Upload started for batch 50 total items 60 for tag fly...
# Batch 50 Image upload completed. Total uploaded 60 for tag fly
# tag creation done with tag id 7da905e5-09e6-4177-a332-0138dd417830
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag fox...
# Batch 0 Image upload completed. Total uploaded 60 for tag fox
# Upload started for batch 25 total items 60 for tag fox...
# Batch 25 Image upload completed. Total uploaded 60 for tag fox
# Upload started for batch 50 total items 60 for tag fox...
# Batch 50 Image upload completed. Total uploaded 60 for tag fox
# tag creation done with tag id 8ed29a3a-2ecb-4f22-954c-e5a1c20b47ae
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag goat...
# Batch 0 Image upload completed. Total uploaded 60 for tag goat
# Upload started for batch 25 total items 60 for tag goat...
# Batch 25 Image upload completed. Total uploaded 60 for tag goat
# Upload started for batch 50 total items 60 for tag goat...
# Batch 50 Image upload completed. Total uploaded 60 for tag goat
# tag creation done with tag id e654c772-eced-4c49-bd92-ed9b7bd32f31
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag goldfish...
# Batch 0 Image upload completed. Total uploaded 60 for tag goldfish
# Upload started for batch 25 total items 60 for tag goldfish...
# Batch 25 Image upload completed. Total uploaded 60 for tag goldfish
# Upload started for batch 50 total items 60 for tag goldfish...
# Batch 50 Image upload completed. Total uploaded 60 for tag goldfish
# tag creation done with tag id ad989cfc-a892-4d69-95ec-b38aad4eb2b6
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag goose...
# Batch 0 Image upload completed. Total uploaded 60 for tag goose
# Upload started for batch 25 total items 60 for tag goose...
# Batch 25 Image upload completed. Total uploaded 60 for tag goose
# Upload started for batch 50 total items 60 for tag goose...
# Batch 50 Image upload completed. Total uploaded 60 for tag goose
# tag creation done with tag id a540d73d-fb4f-4f7a-a5b4-564159ec4acb
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag gorilla...
# Batch 0 Image upload completed. Total uploaded 60 for tag gorilla
# Upload started for batch 25 total items 60 for tag gorilla...
# Image batch upload failed.
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Batch 25 Image upload completed. Total uploaded 60 for tag gorilla
# Upload started for batch 50 total items 60 for tag gorilla...
# Batch 50 Image upload completed. Total uploaded 60 for tag gorilla
# tag creation done with tag id 742bf4e2-b6bd-41af-a734-8e2a1d1041ff
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag grasshopper...
# Batch 0 Image upload completed. Total uploaded 60 for tag grasshopper
# Upload started for batch 25 total items 60 for tag grasshopper...
# Batch 25 Image upload completed. Total uploaded 60 for tag grasshopper
# Upload started for batch 50 total items 60 for tag grasshopper...
# Batch 50 Image upload completed. Total uploaded 60 for tag grasshopper
# tag creation done with tag id c6f79290-0b9a-4785-a06f-2b5f6efb70ea
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hamster...
# Batch 0 Image upload completed. Total uploaded 60 for tag hamster
# Upload started for batch 25 total items 60 for tag hamster...
# Batch 25 Image upload completed. Total uploaded 60 for tag hamster
# Upload started for batch 50 total items 60 for tag hamster...
# Batch 50 Image upload completed. Total uploaded 60 for tag hamster
# tag creation done with tag id 630bba4c-b15b-4688-ba8f-19d227c023c4
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hare...
# Batch 0 Image upload completed. Total uploaded 60 for tag hare
# Upload started for batch 25 total items 60 for tag hare...
# Batch 25 Image upload completed. Total uploaded 60 for tag hare
# Upload started for batch 50 total items 60 for tag hare...
# Batch 50 Image upload completed. Total uploaded 60 for tag hare
# tag creation done with tag id ba4131af-628d-482b-b52b-f848e77d99d5
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hedgehog...
# Batch 0 Image upload completed. Total uploaded 60 for tag hedgehog
# Upload started for batch 25 total items 60 for tag hedgehog...
# Batch 25 Image upload completed. Total uploaded 60 for tag hedgehog
# Upload started for batch 50 total items 60 for tag hedgehog...
# Batch 50 Image upload completed. Total uploaded 60 for tag hedgehog
# tag creation done with tag id da4ec0cb-7699-4a49-91e9-2d59bd4ea6be
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hippopotamus...
# Batch 0 Image upload completed. Total uploaded 60 for tag hippopotamus
# Upload started for batch 25 total items 60 for tag hippopotamus...
# Batch 25 Image upload completed. Total uploaded 60 for tag hippopotamus
# Upload started for batch 50 total items 60 for tag hippopotamus...
# Batch 50 Image upload completed. Total uploaded 60 for tag hippopotamus
# tag creation done with tag id e0d193fc-0905-4a89-9619-30ab7bdf1328
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hornbill...
# Batch 0 Image upload completed. Total uploaded 60 for tag hornbill
# Upload started for batch 25 total items 60 for tag hornbill...
# Batch 25 Image upload completed. Total uploaded 60 for tag hornbill
# Upload started for batch 50 total items 60 for tag hornbill...
# Batch 50 Image upload completed. Total uploaded 60 for tag hornbill
# tag creation done with tag id 3abbc1ba-cf1b-414c-b82f-f94233f4ee49
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag horse...
# Batch 0 Image upload completed. Total uploaded 60 for tag horse
# Upload started for batch 25 total items 60 for tag horse...
# Batch 25 Image upload completed. Total uploaded 60 for tag horse
# Upload started for batch 50 total items 60 for tag horse...
# Batch 50 Image upload completed. Total uploaded 60 for tag horse
# tag creation done with tag id d3685466-47fb-4c31-bf4b-b89530becb8d
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hummingbird...
# Batch 0 Image upload completed. Total uploaded 60 for tag hummingbird
# Upload started for batch 25 total items 60 for tag hummingbird...
# Batch 25 Image upload completed. Total uploaded 60 for tag hummingbird
# Upload started for batch 50 total items 60 for tag hummingbird...
# Batch 50 Image upload completed. Total uploaded 60 for tag hummingbird
# tag creation done with tag id 6d2ccce6-e984-4a51-9d89-b77d90fe7ee0
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag hyena...
# Batch 0 Image upload completed. Total uploaded 60 for tag hyena
# Upload started for batch 25 total items 60 for tag hyena...
# Batch 25 Image upload completed. Total uploaded 60 for tag hyena
# Upload started for batch 50 total items 60 for tag hyena...
# Batch 50 Image upload completed. Total uploaded 60 for tag hyena
# tag creation done with tag id fe3cb201-d3f1-452d-89d7-14dfae089bd7
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag jellyfish...
# Batch 0 Image upload completed. Total uploaded 60 for tag jellyfish
# Upload started for batch 25 total items 60 for tag jellyfish...
# Batch 25 Image upload completed. Total uploaded 60 for tag jellyfish
# Upload started for batch 50 total items 60 for tag jellyfish...
# Batch 50 Image upload completed. Total uploaded 60 for tag jellyfish
# tag creation done with tag id cf3680ac-e670-4282-bf0e-c2af03254980
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag kangaroo...
# Batch 0 Image upload completed. Total uploaded 60 for tag kangaroo
# Upload started for batch 25 total items 60 for tag kangaroo...
# Batch 25 Image upload completed. Total uploaded 60 for tag kangaroo
# Upload started for batch 50 total items 60 for tag kangaroo...
# Batch 50 Image upload completed. Total uploaded 60 for tag kangaroo
# tag creation done with tag id dc8b000f-5dec-4672-bf9f-b9240f8098f3
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag koala...
# Batch 0 Image upload completed. Total uploaded 60 for tag koala
# Upload started for batch 25 total items 60 for tag koala...
# Batch 25 Image upload completed. Total uploaded 60 for tag koala
# Upload started for batch 50 total items 60 for tag koala...
# Batch 50 Image upload completed. Total uploaded 60 for tag koala
# tag creation done with tag id e9687dee-00f8-4123-8f80-cb039249c7e7
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag ladybugs...
# Batch 0 Image upload completed. Total uploaded 60 for tag ladybugs
# Upload started for batch 25 total items 60 for tag ladybugs...
# Batch 25 Image upload completed. Total uploaded 60 for tag ladybugs
# Upload started for batch 50 total items 60 for tag ladybugs...
# Batch 50 Image upload completed. Total uploaded 60 for tag ladybugs
# tag creation done with tag id 60f678a2-f49c-43ca-b56f-4716187d28ef
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag leopard...
# Batch 0 Image upload completed. Total uploaded 60 for tag leopard
# Upload started for batch 25 total items 60 for tag leopard...
# Batch 25 Image upload completed. Total uploaded 60 for tag leopard
# Upload started for batch 50 total items 60 for tag leopard...
# Batch 50 Image upload completed. Total uploaded 60 for tag leopard
# tag creation done with tag id d1ad2451-446b-428f-814e-1f470262a382
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag lion...
# Batch 0 Image upload completed. Total uploaded 60 for tag lion
# Upload started for batch 25 total items 60 for tag lion...
# Batch 25 Image upload completed. Total uploaded 60 for tag lion
# Upload started for batch 50 total items 60 for tag lion...
# Batch 50 Image upload completed. Total uploaded 60 for tag lion
# tag creation done with tag id c72bccc9-3493-4495-a60a-5d8e8c83cb28
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag lizard...
# Batch 0 Image upload completed. Total uploaded 60 for tag lizard
# Upload started for batch 25 total items 60 for tag lizard...
# Batch 25 Image upload completed. Total uploaded 60 for tag lizard
# Upload started for batch 50 total items 60 for tag lizard...
# Batch 50 Image upload completed. Total uploaded 60 for tag lizard
# tag creation done with tag id d4f3816c-da9e-45cc-8261-728852df2b3b
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag lobster...
# Batch 0 Image upload completed. Total uploaded 60 for tag lobster
# Upload started for batch 25 total items 60 for tag lobster...
# Batch 25 Image upload completed. Total uploaded 60 for tag lobster
# Upload started for batch 50 total items 60 for tag lobster...
# Batch 50 Image upload completed. Total uploaded 60 for tag lobster
# tag creation done with tag id 088fe505-4361-45de-a950-587cf189b3d4
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag mosquito...
# Batch 0 Image upload completed. Total uploaded 60 for tag mosquito
# Upload started for batch 25 total items 60 for tag mosquito...
# Batch 25 Image upload completed. Total uploaded 60 for tag mosquito
# Upload started for batch 50 total items 60 for tag mosquito...
# Batch 50 Image upload completed. Total uploaded 60 for tag mosquito
# tag creation done with tag id fae84146-94f9-421d-b523-09f222e6d095
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag moth...
# Batch 0 Image upload completed. Total uploaded 60 for tag moth
# Upload started for batch 25 total items 60 for tag moth...
# Batch 25 Image upload completed. Total uploaded 60 for tag moth
# Upload started for batch 50 total items 60 for tag moth...
# Batch 50 Image upload completed. Total uploaded 60 for tag moth
# tag creation done with tag id 55dd23b9-b7ca-40e2-955c-70926dab08d5
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag mouse...
# Batch 0 Image upload completed. Total uploaded 60 for tag mouse
# Upload started for batch 25 total items 60 for tag mouse...
# Batch 25 Image upload completed. Total uploaded 60 for tag mouse
# Upload started for batch 50 total items 60 for tag mouse...
# Batch 50 Image upload completed. Total uploaded 60 for tag mouse
# tag creation done with tag id 3fa30dd9-8846-48a9-9eef-ba334d20045a
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag octopus...
# Batch 0 Image upload completed. Total uploaded 60 for tag octopus
# Upload started for batch 25 total items 60 for tag octopus...
# Batch 25 Image upload completed. Total uploaded 60 for tag octopus
# Upload started for batch 50 total items 60 for tag octopus...
# Batch 50 Image upload completed. Total uploaded 60 for tag octopus
# tag creation done with tag id 2e121a6d-eb1a-4af8-94ad-1c067dc8b6b2
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag okapi...
# Batch 0 Image upload completed. Total uploaded 60 for tag okapi
# Upload started for batch 25 total items 60 for tag okapi...
# Batch 25 Image upload completed. Total uploaded 60 for tag okapi
# Upload started for batch 50 total items 60 for tag okapi...
# Batch 50 Image upload completed. Total uploaded 60 for tag okapi
# tag creation done with tag id 63217581-1eb3-4104-a8b5-53d88002fb4e
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag orangutan...
# Batch 0 Image upload completed. Total uploaded 60 for tag orangutan
# Upload started for batch 25 total items 60 for tag orangutan...
# Batch 25 Image upload completed. Total uploaded 60 for tag orangutan
# Upload started for batch 50 total items 60 for tag orangutan...
# Batch 50 Image upload completed. Total uploaded 60 for tag orangutan
# tag creation done with tag id a208f30e-8c7e-4b35-a044-d89e1d9fbb73
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag otter...
# Batch 0 Image upload completed. Total uploaded 60 for tag otter
# Upload started for batch 25 total items 60 for tag otter...
# Batch 25 Image upload completed. Total uploaded 60 for tag otter
# Upload started for batch 50 total items 60 for tag otter...
# Batch 50 Image upload completed. Total uploaded 60 for tag otter
# tag creation done with tag id 7aeb7f37-1e34-4f56-bd6a-46c5245d745f
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag owl...
# Batch 0 Image upload completed. Total uploaded 60 for tag owl
# Upload started for batch 25 total items 60 for tag owl...
# Batch 25 Image upload completed. Total uploaded 60 for tag owl
# Upload started for batch 50 total items 60 for tag owl...
# Batch 50 Image upload completed. Total uploaded 60 for tag owl
# tag creation done with tag id a990cf55-886e-476b-9ea0-de7f8879bbd6
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag ox...
# Batch 0 Image upload completed. Total uploaded 60 for tag ox
# Upload started for batch 25 total items 60 for tag ox...
# Batch 25 Image upload completed. Total uploaded 60 for tag ox
# Upload started for batch 50 total items 60 for tag ox...
# Batch 50 Image upload completed. Total uploaded 60 for tag ox
# tag creation done with tag id 7ae95d5e-a00b-4279-9d22-6a14874b7225
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag oyster...
# Batch 0 Image upload completed. Total uploaded 60 for tag oyster
# Upload started for batch 25 total items 60 for tag oyster...
# Batch 25 Image upload completed. Total uploaded 60 for tag oyster
# Upload started for batch 50 total items 60 for tag oyster...
# Batch 50 Image upload completed. Total uploaded 60 for tag oyster
# tag creation done with tag id 731b5d26-1a01-43ef-b786-8cad08a36eb1
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag panda...
# Batch 0 Image upload completed. Total uploaded 60 for tag panda
# Upload started for batch 25 total items 60 for tag panda...
# Batch 25 Image upload completed. Total uploaded 60 for tag panda
# Upload started for batch 50 total items 60 for tag panda...
# Batch 50 Image upload completed. Total uploaded 60 for tag panda
# tag creation done with tag id db6161b4-107b-487d-95dc-8839d238d868
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag parrot...
# Batch 0 Image upload completed. Total uploaded 60 for tag parrot
# Upload started for batch 25 total items 60 for tag parrot...
# Batch 25 Image upload completed. Total uploaded 60 for tag parrot
# Upload started for batch 50 total items 60 for tag parrot...
# Batch 50 Image upload completed. Total uploaded 60 for tag parrot
# tag creation done with tag id d0c297cf-1aaf-4e43-b418-d39694f42196
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag pelecaniformes...
# Batch 0 Image upload completed. Total uploaded 60 for tag pelecaniformes
# Upload started for batch 25 total items 60 for tag pelecaniformes...
# Batch 25 Image upload completed. Total uploaded 60 for tag pelecaniformes
# Upload started for batch 50 total items 60 for tag pelecaniformes...
# Batch 50 Image upload completed. Total uploaded 60 for tag pelecaniformes
# tag creation done with tag id 3b422c93-3e49-40e1-b44c-61b7b65c10d7
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag penguin...
# Batch 0 Image upload completed. Total uploaded 60 for tag penguin
# Upload started for batch 25 total items 60 for tag penguin...
# Batch 25 Image upload completed. Total uploaded 60 for tag penguin
# Upload started for batch 50 total items 60 for tag penguin...
# Batch 50 Image upload completed. Total uploaded 60 for tag penguin
# tag creation done with tag id 0597a6a8-0db3-4343-a3b2-f6e308c96a60
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag pig...
# Batch 0 Image upload completed. Total uploaded 60 for tag pig
# Upload started for batch 25 total items 60 for tag pig...
# Batch 25 Image upload completed. Total uploaded 60 for tag pig
# Upload started for batch 50 total items 60 for tag pig...
# Batch 50 Image upload completed. Total uploaded 60 for tag pig
# tag creation done with tag id 704320ac-8fdb-4c4f-995f-8dfcbaf0abfb
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag pigeon...
# Batch 0 Image upload completed. Total uploaded 60 for tag pigeon
# Upload started for batch 25 total items 60 for tag pigeon...
# Batch 25 Image upload completed. Total uploaded 60 for tag pigeon
# Upload started for batch 50 total items 60 for tag pigeon...
# Batch 50 Image upload completed. Total uploaded 60 for tag pigeon
# tag creation done with tag id 38cec8be-bcb0-4d6f-991f-5eeb36e7e723
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag porcupine...
# Batch 0 Image upload completed. Total uploaded 60 for tag porcupine
# Upload started for batch 25 total items 60 for tag porcupine...
# Batch 25 Image upload completed. Total uploaded 60 for tag porcupine
# Upload started for batch 50 total items 60 for tag porcupine...
# Batch 50 Image upload completed. Total uploaded 60 for tag porcupine
# tag creation done with tag id edf2f022-3499-44a0-b101-a7cf0f519b9e
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag possum...
# Batch 0 Image upload completed. Total uploaded 60 for tag possum
# Upload started for batch 25 total items 60 for tag possum...
# Batch 25 Image upload completed. Total uploaded 60 for tag possum
# Upload started for batch 50 total items 60 for tag possum...
# Batch 50 Image upload completed. Total uploaded 60 for tag possum
# tag creation done with tag id 5b7fa42c-d1c6-43c6-898e-a539d8619485
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag raccoon...
# Batch 0 Image upload completed. Total uploaded 60 for tag raccoon
# Upload started for batch 25 total items 60 for tag raccoon...
# Batch 25 Image upload completed. Total uploaded 60 for tag raccoon
# Upload started for batch 50 total items 60 for tag raccoon...
# Batch 50 Image upload completed. Total uploaded 60 for tag raccoon
# tag creation done with tag id a86bcf82-c386-461a-b621-4588591651e5
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag rat...
# Image batch upload failed.
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Batch 0 Image upload completed. Total uploaded 60 for tag rat
# Upload started for batch 25 total items 60 for tag rat...
# Batch 25 Image upload completed. Total uploaded 60 for tag rat
# Upload started for batch 50 total items 60 for tag rat...
# Batch 50 Image upload completed. Total uploaded 60 for tag rat
# tag creation done with tag id 00f9319c-39ad-4837-bc52-5ab8d7e8c36c
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag reindeer...
# Batch 0 Image upload completed. Total uploaded 60 for tag reindeer
# Upload started for batch 25 total items 60 for tag reindeer...
# Batch 25 Image upload completed. Total uploaded 60 for tag reindeer
# Upload started for batch 50 total items 60 for tag reindeer...
# Batch 50 Image upload completed. Total uploaded 60 for tag reindeer
# tag creation done with tag id 95ea44d6-2166-4d2e-ac62-2b1e3a438f37
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag rhinoceros...
# Batch 0 Image upload completed. Total uploaded 60 for tag rhinoceros
# Upload started for batch 25 total items 60 for tag rhinoceros...
# Batch 25 Image upload completed. Total uploaded 60 for tag rhinoceros
# Upload started for batch 50 total items 60 for tag rhinoceros...
# Batch 50 Image upload completed. Total uploaded 60 for tag rhinoceros
# tag creation done with tag id 5da7ef45-0844-4311-bae1-655eb24c08cc
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag sandpiper...
# Batch 0 Image upload completed. Total uploaded 60 for tag sandpiper
# Upload started for batch 25 total items 60 for tag sandpiper...
# Batch 25 Image upload completed. Total uploaded 60 for tag sandpiper
# Upload started for batch 50 total items 60 for tag sandpiper...
# Batch 50 Image upload completed. Total uploaded 60 for tag sandpiper
# tag creation done with tag id e886fd07-1f93-4826-973e-a2b27c658ffe
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag seahorse...
# Batch 0 Image upload completed. Total uploaded 60 for tag seahorse
# Upload started for batch 25 total items 60 for tag seahorse...
# Batch 25 Image upload completed. Total uploaded 60 for tag seahorse
# Upload started for batch 50 total items 60 for tag seahorse...
# Batch 50 Image upload completed. Total uploaded 60 for tag seahorse
# tag creation done with tag id 540084b0-7653-4765-97fd-4cdc27a27268
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag seal...
# Batch 0 Image upload completed. Total uploaded 60 for tag seal
# Upload started for batch 25 total items 60 for tag seal...
# Batch 25 Image upload completed. Total uploaded 60 for tag seal
# Upload started for batch 50 total items 60 for tag seal...
# Batch 50 Image upload completed. Total uploaded 60 for tag seal
# tag creation done with tag id 798efe19-5fe6-4a45-80fc-23d75613fc0e
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag shark...
# Batch 0 Image upload completed. Total uploaded 60 for tag shark
# Upload started for batch 25 total items 60 for tag shark...
# Batch 25 Image upload completed. Total uploaded 60 for tag shark
# Upload started for batch 50 total items 60 for tag shark...
# Batch 50 Image upload completed. Total uploaded 60 for tag shark
# tag creation done with tag id 8efd5fe1-7612-43ba-b45a-7fb2e5f335f5
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag sheep...
# Batch 0 Image upload completed. Total uploaded 60 for tag sheep
# Upload started for batch 25 total items 60 for tag sheep...
# Batch 25 Image upload completed. Total uploaded 60 for tag sheep
# Upload started for batch 50 total items 60 for tag sheep...
# Batch 50 Image upload completed. Total uploaded 60 for tag sheep
# tag creation done with tag id 4a6de0d8-cbd9-4da8-af4e-af17250d415f
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag snake...
# Batch 0 Image upload completed. Total uploaded 60 for tag snake
# Upload started for batch 25 total items 60 for tag snake...
# Batch 25 Image upload completed. Total uploaded 60 for tag snake
# Upload started for batch 50 total items 60 for tag snake...
# Batch 50 Image upload completed. Total uploaded 60 for tag snake
# tag creation done with tag id 1c3520fd-e36e-4ed5-bce9-77746b66ac00
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag sparrow...
# Batch 0 Image upload completed. Total uploaded 60 for tag sparrow
# Upload started for batch 25 total items 60 for tag sparrow...
# Batch 25 Image upload completed. Total uploaded 60 for tag sparrow
# Upload started for batch 50 total items 60 for tag sparrow...
# Batch 50 Image upload completed. Total uploaded 60 for tag sparrow
# tag creation done with tag id a833ea1e-0848-4245-90e9-01d0f6194b28
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag squid...
# Batch 0 Image upload completed. Total uploaded 60 for tag squid
# Upload started for batch 25 total items 60 for tag squid...
# Batch 25 Image upload completed. Total uploaded 60 for tag squid
# Upload started for batch 50 total items 60 for tag squid...
# Batch 50 Image upload completed. Total uploaded 60 for tag squid
# tag creation done with tag id 45e8dacc-d976-44f9-b138-7b62401a668e
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag squirrel...
# Batch 0 Image upload completed. Total uploaded 60 for tag squirrel
# Upload started for batch 25 total items 60 for tag squirrel...
# Batch 25 Image upload completed. Total uploaded 60 for tag squirrel
# Upload started for batch 50 total items 60 for tag squirrel...
# Batch 50 Image upload completed. Total uploaded 60 for tag squirrel
# tag creation done with tag id 6b37b351-5082-4e9a-8768-a66e07f3cfca
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag starfish...
# Batch 0 Image upload completed. Total uploaded 60 for tag starfish
# Upload started for batch 25 total items 60 for tag starfish...
# Batch 25 Image upload completed. Total uploaded 60 for tag starfish
# Upload started for batch 50 total items 60 for tag starfish...
# Batch 50 Image upload completed. Total uploaded 60 for tag starfish
# tag creation done with tag id ac899736-aedd-4744-bf50-822d98eb18a2
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag swan...
# Batch 0 Image upload completed. Total uploaded 60 for tag swan
# Upload started for batch 25 total items 60 for tag swan...
# Batch 25 Image upload completed. Total uploaded 60 for tag swan
# Upload started for batch 50 total items 60 for tag swan...
# Batch 50 Image upload completed. Total uploaded 60 for tag swan
# tag creation done with tag id 52be44ae-10ce-4f5b-af6b-d0a2460da0fa
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag tiger...
# Batch 0 Image upload completed. Total uploaded 60 for tag tiger
# Upload started for batch 25 total items 60 for tag tiger...
# Batch 25 Image upload completed. Total uploaded 60 for tag tiger
# Upload started for batch 50 total items 60 for tag tiger...
# Batch 50 Image upload completed. Total uploaded 60 for tag tiger
# tag creation done with tag id c6dbc287-63f4-4523-9d57-bfd573dbdeea
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag turkey...
# Batch 0 Image upload completed. Total uploaded 60 for tag turkey
# Upload started for batch 25 total items 60 for tag turkey...
# Batch 25 Image upload completed. Total uploaded 60 for tag turkey
# Upload started for batch 50 total items 60 for tag turkey...
# Batch 50 Image upload completed. Total uploaded 60 for tag turkey
# tag creation done with tag id 1564bd87-545c-47b9-9ff1-80c94fc21403
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag turtle...
# Batch 0 Image upload completed. Total uploaded 60 for tag turtle
# Upload started for batch 25 total items 60 for tag turtle...
# Batch 25 Image upload completed. Total uploaded 60 for tag turtle
# Upload started for batch 50 total items 60 for tag turtle...
# Batch 50 Image upload completed. Total uploaded 60 for tag turtle
# tag creation done with tag id e30391c8-344b-420f-932d-b65f2ab3e307
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag whale...
# Batch 0 Image upload completed. Total uploaded 60 for tag whale
# Upload started for batch 25 total items 60 for tag whale...
# Batch 25 Image upload completed. Total uploaded 60 for tag whale
# Upload started for batch 50 total items 60 for tag whale...
# Batch 50 Image upload completed. Total uploaded 60 for tag whale
# tag creation done with tag id 51cc2bcf-7482-4c2a-95fd-1ae833f135ee
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag wolf...
# Batch 0 Image upload completed. Total uploaded 60 for tag wolf
# Upload started for batch 25 total items 60 for tag wolf...
# Batch 25 Image upload completed. Total uploaded 60 for tag wolf
# Upload started for batch 50 total items 60 for tag wolf...
# Batch 50 Image upload completed. Total uploaded 60 for tag wolf
# tag creation done with tag id c4ba18e5-0195-4dc4-85a1-db4cee4dd73b
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag wombat...
# Batch 0 Image upload completed. Total uploaded 60 for tag wombat
# Upload started for batch 25 total items 60 for tag wombat...
# Batch 25 Image upload completed. Total uploaded 60 for tag wombat
# Upload started for batch 50 total items 60 for tag wombat...
# Batch 50 Image upload completed. Total uploaded 60 for tag wombat
# tag creation done with tag id 1c6ee844-97f7-411e-ab03-dcccd07ffd47
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag woodpecker...
# Batch 0 Image upload completed. Total uploaded 60 for tag woodpecker
# Upload started for batch 25 total items 60 for tag woodpecker...
# Batch 25 Image upload completed. Total uploaded 60 for tag woodpecker
# Upload started for batch 50 total items 60 for tag woodpecker...
# Batch 50 Image upload completed. Total uploaded 60 for tag woodpecker
# tag creation done with tag id 94933819-a8ed-4df9-9c97-e1edc00340ca
# image_list created with length 60
# Upload started for batch 0 total items 60 for tag zebra...
# Batch 0 Image upload completed. Total uploaded 60 for tag zebra
# Upload started for batch 25 total items 60 for tag zebra...
# Batch 25 Image upload completed. Total uploaded 60 for tag zebra
# Upload started for batch 50 total items 60 for tag zebra...
# Batch 50 Image upload completed. Total uploaded 60 for tag zebra
